# %%
# 10 students, 2 classes, 4 exams, 3 attempts allowed, take student name and exam_name as input
# show in which class the student get maximum marks


students = {"arif":

    {"cnc" : {"quiz1":40,
        "quiz2":45,
        "mid":50,
        "final":55},
"aic" : {"quiz1":40,
        "quiz2":45,
        "mid":50,
        "final":55}
    },
    
    
"ali":

    {"cnc" : {"quiz1":40,
        "quiz2":45,
        "mid":50,
        "final":55},
"aic" : {"quiz1":40,
        "quiz2":45,
        "mid":50,
        "final":55}
    },
    
    
"ahad":

    {"cnc" : {"quiz1":40,
        "quiz2":45,
        "mid":50,
        "final":55},
"aic" : {"quiz1":40,
        "quiz2":45,
        "mid":50,
        "final":55}
    },
    
    
"mir":

    {"cnc" : {"quiz1":40,
        "quiz2":45,
        "mid":50,
        "final":55},
"raza" : {"quiz1":40,
        "quiz2":45,
        "mid":50,
        "final":55}
    },
    
    
"zain":

    {"cnc" : {"quiz1":40,
        "quiz2":45,
        "mid":50,
        "final":55},
"aic" : {"quiz1":40,
        "quiz2":45,
        "mid":50,
        "final":55}
    },
    
    
"safi":

    {"cnc" : {"quiz1":40,
        "quiz2":45,
        "mid":50,
        "final":55},
"aic" : {"quiz1":40,
        "quiz2":45,
        "mid":50,
        "final":55}
    },
    
    
"saif":

    {"cnc" : {"quiz1":40,
        "quiz2":45,
        "mid":50,
        "final":55},
"aic" : {"quiz1":40,
        "quiz2":45,
        "mid":50,
        "final":55}
    },
    
    
"bilal":

    {"cnc" : {"quiz1":40,
        "quiz2":45,
        "mid":50,
        "final":55},
"aic" : {"quiz1":40,
        "quiz2":45,
        "mid":50,
        "final":55}
    },
    
    
"shuja":

    {"cnc" : {"quiz1":40,
        "quiz2":45,
        "mid":50,
        "final":55},
"aic" : {"quiz1":40,
        "quiz2":45,
        "mid":50,
        "final":55}
    }}

student_name = input("Enter student name: ")
student_class = input("Enter student class: ")
exam_name = input("Enter exam: ")

print("Student", student_name , "marks in class" , student_class, "and exam", exam_name  , "are" , students[student_name][student_class][exam_name])
# Out:
# Enter student name: saif
# Enter student class: aic
# Enter exam: quiz1
# Student saif marks in class aic and exam quiz1 are 40
